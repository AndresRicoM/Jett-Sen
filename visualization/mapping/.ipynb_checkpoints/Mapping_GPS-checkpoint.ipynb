# %%
from h3 import h3
import pandas as pd
import geopandas as gpd
from shapely.geometry import *
import warnings
import os
warnings.filterwarnings('ignore')
import pandas
from datetime import datetime
import pytz

# %%
from cartoframes.data import Dataset
from cartoframes.viz import *
from cartoframes.viz.helpers import *
from cartoframes.viz.widgets import *
from cartoframes.auth import set_default_credentials

# %%
# get the carto access key (you need to run env.sh)
CARTO_KEY = os.environ['CARTO_KEY']

# %%
username = 'cityscience_admin'
set_default_credentials(base_url='https://{}.carto.com'.format(username), api_key=CARTO_KEY)

# %%
# load data
data_dir = './gps_data'
file_path = 'trip_2019-11-07T08_47_36-0500_B63DD96A-C519-4300-AC34-44A92F94EE09_8997C1B9-4101-4901-9E73-AB204E60DBEF.csv'
header = ['timestamp', 'latitude', 'longitude']
path = os.path.join(data_dir, file_path)
df = pandas.read_csv(path, header=None)
df.columns = header

print(df)
# Out:
#        timestamp   latitude  longitude
# 0     1573134350  42.355555 -71.103624
# 1     1573134361  42.355463 -71.103528
# 2     1573134456  42.355317 -71.103248
# 3     1573134456  42.355577 -71.103798
# 4     1573134457  42.355577 -71.103798
# ...          ...        ...        ...
# 1583  1573134871  42.364331 -71.096514
# 1584  1573134871  42.364331 -71.096514
# 1585  1573134872  42.364331 -71.096514
# 1586  1573134872  42.364331 -71.096514
# 1587  1573134872  42.364331 -71.096514
#
# [1588 rows x 3 columns]

# %%
Map(Layer(df))
# Out:
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#   <!-- Include CARTO VL JS -->
#   <script src=&quot;https://libs.cartocdn.com/carto-vl/v1.4/carto-vl.min.js&quot;></script>
#   <!-- Include Mapbox GL JS -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js&quot;></script>
#   <!-- Include Mapbox GL CSS -->
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; />
#
#   <!-- Include Airship -->
#   <script nomodule=&quot;&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.2.0-rc.2.1/airship.js&quot;></script>
# ...

# %%
clustered_dir = '../clustered_data/'
cl_file = 'clustered_2019-11-07 08:47:36.127124.txt'
# cl_file = 'clustered_2019-11-07 09:04:41.429133.txt'
path = os.path.join(clustered_dir, cl_file)
cl_data = pandas.read_csv(path, header=None)[[0,10]]

print(cl_data)

# unclustered_dir = '../hackbikARICOM/saturn_data/main_data'
# unclustered_dir = '/home/yasushi/code/Jett-Sen/hackbikeARICOM/saturn_data/main_data'
# unclustered_file = '2019-11-07 08:47:36.127124.txt'
# path = os.path.join(unclustered_dir, unclustered_file)
# ucl_data = pandas.read_csv(path, header=None)

# print(len(ucl_data))
# Out:
#                0   10
# 0     08:47:36.14   1
# 1     08:47:36.22   1
# 2     08:47:36.29   1
# 3     08:47:36.35   1
# 4     08:47:36.42   1
# ...           ...  ..
# 5882  08:54:33.28   3
# 5883  08:54:33.38   3
# 5884  08:54:33.45   3
# 5885  08:54:33.51   3
# 5886  08:54:33.58   3
#
# [5887 rows x 2 columns]

# %%
# parse time
test_string = '08:47:36.14'
date_object = datetime.strptime(test_string, "%H:%M:%S.%f")
date_object = date_object.replace(year=2019)
date_object = date_object.replace(month=11)
date_object = date_object.replace(day=7)
eastern = pytz.timezone('US/Eastern')
date_object = date_object.replace(tzinfo=eastern)

print(date_object)

sample_ts = 1573134350
date_object = datetime.fromtimestamp(sample_ts)
print(date_object)

# so this means that there are two timestamps.... 
# the 08:47 is from the raspi, where it has been passed to the iphone.
# the GPS points (starting from 08:45:50) are using the iphone internal time
# Out:
# 2019-11-07 08:47:36.140000-04:56
# 2019-11-07 08:45:50
